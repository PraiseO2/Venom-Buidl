# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read CSV file

# %%
df = pd.read_csv('NFT_Top_Collections.csv', na_filter=False)
df
# Out:
#      Index                               Name    Volume    Volume_USD  \
# 0        0                      basis.markets  27256.63  4.001818e+06
# 1        1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2        2                           Flippies   6732.19  9.884201e+05
# 3        3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4        4                      Stylish Studs   3191.15  4.685246e+05
# ..     ...                                ...       ...           ...
# 587    595                NEO MONKEY BUSINESS      0.00  0.000000e+00
# 588    596                          Cops Game      0.00  0.000000e+00
# 589    597                   Floppa Syndicate      0.00  0.000000e+00
# 590    598                           Duck BRO      0.00  0.000000e+00
# 591    599                         CryptoPets      0.00  0.000000e+00
#
#       Market_Cap  Market_Cap_USD  Sales Floor_Price Floor_Price_USD  \
# 0     708.145455    103969.91560    366        39.5         5799.39
# 1     106.656000     15659.23392   2075        0.67         98.3694
# 2    1663.863158    244288.38880   1504         0.8         117.456
# 3      90.275000     13254.17550    395        3.79        556.4478
# 4     165.000000     24225.30000    729         4.3         631.326
# ..           ...             ...    ...         ...             ...
# 587     0.000000         0.00000      0        0.59         86.6238
# 588     0.000000         0.00000      0        3.99        585.8118
# 589     0.000000         0.00000      0
# 590     0.000000         0.00000      0         0.2          29.364
# 591     0.000000         0.00000      0         1.4         205.548
#
#      Average_Price  Average_Price_USD  Owners  Assets Owner_Asset_Ratio  \
# 0        74.471667       10933.930100      12      16                75
# 1         5.484940         805.298855     103     132             78.03
# 2         4.476190         657.194239     905    1638             55.25
# 3         9.455089        1388.196109      19      23             82.61
# 4         4.377435         642.694984      28      50                56
# ..             ...                ...     ...     ...               ...
# 587       0.000000           0.000000       1       2                50
# 588       0.000000           0.000000       4       4               100
# 589       0.000000           0.000000       0       2
# 590       0.000000           0.000000      38      56             67.86
# 591       0.000000           0.000000      16      23             69.57
#
#                                 Category                            Website  \
# 0         Collectibles,Digital,Privilege             https://basis.markets/
# 1                                                 https://skeletoncrew.rip/
# 2                                                 https://www.flippies.art/
# 3                                         https://meerkatmillionaires.club/
# 4                                                   https://stylishstuds.io
# ..                                   ...                                ...
# 587                                                      neomonkey.business
# 588                                                      https://cops.game/
# 589  2D,Art,Digital,Collectibles,Drawing
# 590                           Art,PFP,2D
# 591                                                 https://cryptopets.tech
#
#                                                   Logo
# 0    https://content.solsea.io/files/thumbnail/1636...
# 1    https://content.solsea.io/files/thumbnail/1633...
# 2    https://content.solsea.io/files/thumbnail/1632...
# 3    https://content.solsea.io/files/thumbnail/1632...
# 4    https://content.solsea.io/files/thumbnail/1632...
# ..                                                 ...
# 587  https://content.solsea.io/files/thumbnail/1641...
# 588  https://content.solsea.io/files/thumbnail/1641...
# 589  https://content.solsea.io/files/thumbnail/1641...
# 590  https://content.solsea.io/files/thumbnail/1642...
# 591  https://content.solsea.io/files/thumbnail/1642...
#
# [592 rows x 17 columns]

# %% [markdown]
# ##### Split Table into 2 tables. (USD and SOLONA)

# %%
nft = df[['Index', 'Name', 'Volume', 'Market_Cap', 'Sales', 'Floor_Price', 'Average_Price', 'Owners', 'Assets', 'Owner_Asset_Ratio', 'Category', 'Website', 'Logo']]
nft_usd = df[['Index', 'Name', 'Volume_USD', 'Market_Cap_USD', 'Sales', 'Floor_Price_USD', 'Average_Price_USD', 'Owners', 'Assets', 'Owner_Asset_Ratio', 'Category', 'Website', 'Logo']]
nft
# Out:
#      Index                               Name    Volume   Market_Cap  Sales  \
# 0        0                      basis.markets  27256.63   708.145455    366
# 1        1               Skeleton Crew Skulls  11381.25   106.656000   2075
# 2        2                           Flippies   6732.19  1663.863158   1504
# 3        3  Meerkat Millionaires Country Club   3734.76    90.275000    395
# 4        4                      Stylish Studs   3191.15   165.000000    729
# ..     ...                                ...       ...          ...    ...
# 587    595                NEO MONKEY BUSINESS      0.00     0.000000      0
# 588    596                          Cops Game      0.00     0.000000      0
# 589    597                   Floppa Syndicate      0.00     0.000000      0
# 590    598                           Duck BRO      0.00     0.000000      0
# 591    599                         CryptoPets      0.00     0.000000      0
#
#     Floor_Price  Average_Price  Owners  Assets Owner_Asset_Ratio  \
# 0          39.5      74.471667      12      16                75
# 1          0.67       5.484940     103     132             78.03
# 2           0.8       4.476190     905    1638             55.25
# 3          3.79       9.455089      19      23             82.61
# 4           4.3       4.377435      28      50                56
# ..          ...            ...     ...     ...               ...
# 587        0.59       0.000000       1       2                50
# 588        3.99       0.000000       4       4               100
# 589                   0.000000       0       2
# 590         0.2       0.000000      38      56             67.86
# 591         1.4       0.000000      16      23             69.57
#
#                                 Category                            Website  \
# 0         Collectibles,Digital,Privilege             https://basis.markets/
# 1                                                 https://skeletoncrew.rip/
# 2                                                 https://www.flippies.art/
# 3                                         https://meerkatmillionaires.club/
# 4                                                   https://stylishstuds.io
# ..                                   ...                                ...
# 587                                                      neomonkey.business
# 588                                                      https://cops.game/
# 589  2D,Art,Digital,Collectibles,Drawing
# 590                           Art,PFP,2D
# 591                                                 https://cryptopets.tech
#
#                                                   Logo
# 0    https://content.solsea.io/files/thumbnail/1636...
# 1    https://content.solsea.io/files/thumbnail/1633...
# 2    https://content.solsea.io/files/thumbnail/1632...
# 3    https://content.solsea.io/files/thumbnail/1632...
# 4    https://content.solsea.io/files/thumbnail/1632...
# ..                                                 ...
# 587  https://content.solsea.io/files/thumbnail/1641...
# 588  https://content.solsea.io/files/thumbnail/1641...
# 589  https://content.solsea.io/files/thumbnail/1641...
# 590  https://content.solsea.io/files/thumbnail/1642...
# 591  https://content.solsea.io/files/thumbnail/1642...
#
# [592 rows x 13 columns]

# %% [markdown]
# ## Data Describing

# %%
nft.shape
# Out:
# (592, 13)

# %%
nft.columns
# Out:
# Index(['Index', 'Name', 'Volume', 'Market_Cap', 'Sales', 'Floor_Price',
#        'Average_Price', 'Owners', 'Assets', 'Owner_Asset_Ratio', 'Category',
#        'Website', 'Logo'],
#       dtype='object')

# %%
nft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              592 non-null    int64
#  1   Name               592 non-null    object
#  2   Volume             592 non-null    float64
#  3   Market_Cap         592 non-null    float64
#  4   Sales              592 non-null    int64
#  5   Floor_Price        592 non-null    object
#  6   Average_Price      592 non-null    float64
#  7   Owners             592 non-null    int64
#  8   Assets             592 non-null    int64
#  9   Owner_Asset_Ratio  592 non-null    object
#  10  Category           592 non-null    object
#  11  Website            592 non-null    object
#  12  Logo               592 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 60.2+ KB

# %%
nft.describe()
# Out:
#             Index        Volume   Market_Cap        Sales  Average_Price  \
# count  592.000000    592.000000   592.000000   592.000000     592.000000
# mean   296.547297    197.548885    45.134817   164.491554       2.373566
# std    172.520622   1283.031435   179.327166   451.321395      15.035229
# min      0.000000      0.000000     0.000000     0.000000       0.000000
# 25%    147.750000      7.300000     0.000000    11.000000       0.306029
# 50%    295.500000     18.595000     0.000000    35.000000       0.720412
# 75%    444.250000     80.825000    21.841974   107.250000       1.596750
# max    599.000000  27256.630000  2530.877143  5229.000000     347.500000
#
#             Owners       Assets
# count   592.000000   592.000000
# mean     53.731419   116.694257
# std     133.893752   251.598765
# min       0.000000     0.000000
# 25%       4.000000    10.000000
# 50%      15.000000    38.000000
# 75%      44.000000   102.250000
# max    2041.000000  3320.000000

# %%
nft.corr()
# Out:
# C:\Users\CEO\AppData\Local\Temp\ipykernel_11320\3878372546.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nft.corr()
#                   Index    Volume  Market_Cap     Sales  Average_Price  \
# Index          1.000000 -0.230818   -0.313816 -0.399051      -0.132229
# Volume        -0.230818  1.000000    0.356760  0.239926       0.201824
# Market_Cap    -0.313816  0.356760    1.000000  0.404380       0.021315
# Sales         -0.399051  0.239926    0.404380  1.000000      -0.028473
# Average_Price -0.132229  0.201824    0.021315 -0.028473       1.000000
# Owners        -0.296293  0.146440    0.419220  0.811492      -0.041485
# Assets        -0.299876  0.128694    0.539007  0.753750      -0.049250
#
#                  Owners    Assets
# Index         -0.296293 -0.299876
# Volume         0.146440  0.128694
# Market_Cap     0.419220  0.539007
# Sales          0.811492  0.753750
# Average_Price -0.041485 -0.049250
# Owners         1.000000  0.909380
# Assets         0.909380  1.000000

# %% [markdown]
# ## Data Wrangling

# %%
count_missing = pd.DataFrame({
    'Missing Values' : nft.isna().sum(),
    'Percentage' : nft.isna().sum()/len(nft)*100
})
count_missing
# Out:
#                    Missing Values  Percentage
# Index                           0         0.0
# Name                            0         0.0
# Volume                          0         0.0
# Market_Cap                      0         0.0
# Sales                           0         0.0
# Floor_Price                     0         0.0
# Average_Price                   0         0.0
# Owners                          0         0.0
# Assets                          0         0.0
# Owner_Asset_Ratio               0         0.0
# Category                        0         0.0
# Website                         0         0.0
# Logo                            0         0.0

# %% [markdown]
# #### Drop Unnecessary Features

# %%
try:
    nft.drop(columns = ["Category","Website","Logo"], inplace = True)
    print('Drop successfully')
except:
    print("You've already dropped those features")
# Out:
# Drop successfully
# C:\Users\CEO\AppData\Local\Temp\ipykernel_11320\662534443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nft.drop(columns = ["Category","Website","Logo"], inplace = True)

# %% [markdown]
# # Cross-check Edit

# %%
nft
# Out:
#      Index                               Name    Volume   Market_Cap  Sales  \
# 0        0                      basis.markets  27256.63   708.145455    366
# 1        1               Skeleton Crew Skulls  11381.25   106.656000   2075
# 2        2                           Flippies   6732.19  1663.863158   1504
# 3        3  Meerkat Millionaires Country Club   3734.76    90.275000    395
# 4        4                      Stylish Studs   3191.15   165.000000    729
# ..     ...                                ...       ...          ...    ...
# 587    595                NEO MONKEY BUSINESS      0.00     0.000000      0
# 588    596                          Cops Game      0.00     0.000000      0
# 589    597                   Floppa Syndicate      0.00     0.000000      0
# 590    598                           Duck BRO      0.00     0.000000      0
# 591    599                         CryptoPets      0.00     0.000000      0
#
#     Floor_Price  Average_Price  Owners  Assets Owner_Asset_Ratio
# 0          39.5      74.471667      12      16                75
# 1          0.67       5.484940     103     132             78.03
# 2           0.8       4.476190     905    1638             55.25
# 3          3.79       9.455089      19      23             82.61
# 4           4.3       4.377435      28      50                56
# ..          ...            ...     ...     ...               ...
# 587        0.59       0.000000       1       2                50
# 588        3.99       0.000000       4       4               100
# 589                   0.000000       0       2
# 590         0.2       0.000000      38      56             67.86
# 591         1.4       0.000000      16      23             69.57
#
# [592 rows x 10 columns]

# %% [markdown]
# #### Drop Duplicate Values

# %%
nft[nft.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Volume, Market_Cap, Sales, Floor_Price, Average_Price, Owners, Assets, Owner_Asset_Ratio]
# Index: []

# %% [markdown]
# There are no missing values.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Top10: Volume

# %%
top_volume = nft.head(10).sort_values(by='Volume')
plt.subplots(figsize=(16,10))
sns.barplot(x=top_volume.Name,y=top_volume.Volume,palette = "winter")
plt.xticks(rotation = 90)
plt.xlabel("NFT Project Name",fontsize =30)
plt.ylabel("NFT Volume (SOL)",fontsize =30)
plt.title("Top 10 NFT that have the most Volume",fontsize =50)
plt.show()

display(nft.sort_values(by='Volume', ascending=False).head(10))
# Out:
#    Index                               Name    Volume   Market_Cap  Sales  \
# 0      0                      basis.markets  27256.63   708.145455    366
# 1      1               Skeleton Crew Skulls  11381.25   106.656000   2075
# 2      2                           Flippies   6732.19  1663.863158   1504
# 3      3  Meerkat Millionaires Country Club   3734.76    90.275000    395
# 4      4                      Stylish Studs   3191.15   165.000000    729
# 5      5                           I'M AIKO   2904.70  2530.877143   1411
# 6      6                       Crypto Idolz   2315.74  1168.041981   1418
# 7      7        Megalodon Rogue Shark Tooth   2116.61    60.050375   5229
# 8      8                        CorruptCatz   1983.92   345.790000   1489
# 9      9                        Meta Waifus   1844.59   989.491267   1156
#
#   Floor_Price  Average_Price  Owners  Assets Owner_Asset_Ratio
# 0        39.5      74.471667      12      16                75
# 1        0.67       5.484940     103     132             78.03
# 2         0.8       4.476190     905    1638             55.25
# 3        3.79       9.455089      19      23             82.61
# 4         4.3       4.377435      28      50                56
# 5         1.2       2.058611     599    1206             49.67
# 6         0.6       1.633103     244     529             46.12
# 7        0.04       0.404783     946    1309             72.27
# 8         0.1       1.332384     636     916             69.43
# 9        1.27       1.595666     376     643             58.48

# %% [markdown]
# #### Top10: Market Cap

# %%
top_marketcap = nft.head(10).sort_values(by='Market_Cap')
plt.subplots(figsize=(16,10))
sns.barplot(x=top_marketcap.Name, y=top_marketcap.Market_Cap, palette='summer')
plt.xticks(rotation=90)
plt.xlabel("NFT Project Name",fontsize =30)
plt.ylabel("Market Cap", fontsize=30)
plt.show()

display(nft.sort_values(by='Market_Cap', ascending=False).head(10))
# Out:
#     Index                  Name    Volume   Market_Cap  Sales Floor_Price  \
# 5       5              I'M AIKO   2904.70  2530.877143   1411         1.2
# 2       2              Flippies   6732.19  1663.863158   1504         0.8
# 43     43    CoinCards (Solana)    422.44  1368.147826    506         0.3
# 6       6          Crypto Idolz   2315.74  1168.041981   1418         0.6
# 9       9           Meta Waifus   1844.59   989.491267   1156        1.27
# 15     15  Crypto Idolz - Faces    990.64   962.156774   1264        0.25
# 34     34   MyRareFrog (Solana)    518.81   936.992857    579        0.85
# 10     10  Crypto Idolz - Butts   1756.29   910.915461   2906        0.24
# 0       0         basis.markets  27256.63   708.145455    366        39.5
# 29     29      SOL NFL Player's    643.51   624.494063    411        0.25
#
#     Average_Price  Owners  Assets Owner_Asset_Ratio
# 5        2.058611     599    1206             49.67
# 2        4.476190     905    1638             55.25
# 43       0.834862      56     860              6.51
# 6        1.633103     244     529             46.12
# 9        1.595666     376     643             58.48
# 15       0.783734     388    1239             31.32
# 34       0.896045      15     466              3.22
# 10       0.604367     413     847             48.76
# 0       74.471667      12      16                75
# 29       1.565718     304     451             67.41

# %% [markdown]
# #### Top10: Sales

# %%
top_sale = nft.head(10).sort_values(by='Sales')
plt.subplots(figsize =(16,10))
sns.barplot(x=top_sale.Name, y=top_sale.Sales, palette='rocket')
plt.xticks(rotation=90)
plt.ylabel('Sales', fontsize=30)
plt.xlabel('NFT Project Name', fontsize=30)
plt.show()
display(nft.head(10).sort_values(by='Sales', ascending=False))
# Out:
#    Index                               Name    Volume   Market_Cap  Sales  \
# 7      7        Megalodon Rogue Shark Tooth   2116.61    60.050375   5229
# 1      1               Skeleton Crew Skulls  11381.25   106.656000   2075
# 2      2                           Flippies   6732.19  1663.863158   1504
# 8      8                        CorruptCatz   1983.92   345.790000   1489
# 6      6                       Crypto Idolz   2315.74  1168.041981   1418
# 5      5                           I'M AIKO   2904.70  2530.877143   1411
# 9      9                        Meta Waifus   1844.59   989.491267   1156
# 4      4                      Stylish Studs   3191.15   165.000000    729
# 3      3  Meerkat Millionaires Country Club   3734.76    90.275000    395
# 0      0                      basis.markets  27256.63   708.145455    366
#
#   Floor_Price  Average_Price  Owners  Assets Owner_Asset_Ratio
# 7        0.04       0.404783     946    1309             72.27
# 1        0.67       5.484940     103     132             78.03
# 2         0.8       4.476190     905    1638             55.25
# 8         0.1       1.332384     636     916             69.43
# 6         0.6       1.633103     244     529             46.12
# 5         1.2       2.058611     599    1206             49.67
# 9        1.27       1.595666     376     643             58.48
# 4         4.3       4.377435      28      50                56
# 3        3.79       9.455089      19      23             82.61
# 0        39.5      74.471667      12      16                75

# %% [markdown]
# #### Top10: Average Price

# %%
top_avg = nft.head(10).sort_values(by='Average_Price')
plt.subplots(figsize=(16,10))
sns.barplot(x=top_avg.Name, y=top_avg.Average_Price, palette='spring')
plt.xticks(rotation=90)
plt.ylabel("Average Price", fontsize=30)
plt.xlabel("NFT Project Name", fontsize=30)
plt.show()

display(nft.head(10).sort_values(by='Average_Price', ascending=True))
# Out:
#    Index                               Name    Volume   Market_Cap  Sales  \
# 7      7        Megalodon Rogue Shark Tooth   2116.61    60.050375   5229
# 8      8                        CorruptCatz   1983.92   345.790000   1489
# 9      9                        Meta Waifus   1844.59   989.491267   1156
# 6      6                       Crypto Idolz   2315.74  1168.041981   1418
# 5      5                           I'M AIKO   2904.70  2530.877143   1411
# 4      4                      Stylish Studs   3191.15   165.000000    729
# 2      2                           Flippies   6732.19  1663.863158   1504
# 1      1               Skeleton Crew Skulls  11381.25   106.656000   2075
# 3      3  Meerkat Millionaires Country Club   3734.76    90.275000    395
# 0      0                      basis.markets  27256.63   708.145455    366
#
#   Floor_Price  Average_Price  Owners  Assets Owner_Asset_Ratio
# 7        0.04       0.404783     946    1309             72.27
# 8         0.1       1.332384     636     916             69.43
# 9        1.27       1.595666     376     643             58.48
# 6         0.6       1.633103     244     529             46.12
# 5         1.2       2.058611     599    1206             49.67
# 4         4.3       4.377435      28      50                56
# 2         0.8       4.476190     905    1638             55.25
# 1        0.67       5.484940     103     132             78.03
# 3        3.79       9.455089      19      23             82.61
# 0        39.5      74.471667      12      16                75

# %%
nft.corr()
plt.figure(figsize=(16, 12))
sns.heatmap(nft.corr(), cmap="rocket")
nft.corr()
# Out:
# C:\Users\CEO\AppData\Local\Temp\ipykernel_11320\1693950025.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nft.corr()
# C:\Users\CEO\AppData\Local\Temp\ipykernel_11320\1693950025.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(nft.corr(), cmap="rocket")
# C:\Users\CEO\AppData\Local\Temp\ipykernel_11320\1693950025.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nft.corr()
#                   Index    Volume  Market_Cap     Sales  Average_Price  \
# Index          1.000000 -0.230818   -0.313816 -0.399051      -0.132229
# Volume        -0.230818  1.000000    0.356760  0.239926       0.201824
# Market_Cap    -0.313816  0.356760    1.000000  0.404380       0.021315
# Sales         -0.399051  0.239926    0.404380  1.000000      -0.028473
# Average_Price -0.132229  0.201824    0.021315 -0.028473       1.000000
# Owners        -0.296293  0.146440    0.419220  0.811492      -0.041485
# Assets        -0.299876  0.128694    0.539007  0.753750      -0.049250
#
#                  Owners    Assets
# Index         -0.296293 -0.299876
# Volume         0.146440  0.128694
# Market_Cap     0.419220  0.539007
# Sales          0.811492  0.753750
# Average_Price -0.041485 -0.049250
# Owners         1.000000  0.909380
# Assets         0.909380  1.000000

# %%
sns.pairplot(nft)
plt.show()

# %% [markdown]
# #### Feature: Assets and Owner

# %%
# nft_assets = nft.groupby(['Owner'])['Assets'].mean().reset_index()

plt.figure(figsize=(18,8))
sns.barplot(x = "Owners",y="Assets",data = nft,
            edgecolor=sns.color_palette("dark", 3))
plt.title('Owners with Assets', fontsize=15)
plt.xlabel('Owners', fontsize=12)
plt.ylabel('Assets', fontsize=12)
# Out:
# Text(0, 0.5, 'Assets')

# %% [markdown]
# #### Feature: Sales and Owners

# %%
plt.figure(figsize=(18,8))
sns.barplot(x = "Owners",y="Sales",data = nft)
plt.title('Owners with Assets', fontsize=15)
plt.xlabel('Owners', fontsize=12)
plt.ylabel('Assets', fontsize=12)
# Out:
# Text(0, 0.5, 'Assets')

# %% [markdown]
# ## Trainning Model

# %% [markdown]
# #### Data Preprocessing

# %%
##transforming data so that it fits within a specific scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_sc = nft[['Owners','Assets','Market_Cap','Sales']]
df_sc = pd.DataFrame(scaler.fit_transform(df_sc), columns=df_sc.columns)
df_sc.head()
# Out:
#      Owners    Assets  Market_Cap     Sales
# 0  0.005879  0.004819    0.279802  0.069994
# 1  0.050465  0.039759    0.042142  0.396825
# 2  0.443410  0.493373    0.657425  0.287627
# 3  0.009309  0.006928    0.035669  0.075540
# 4  0.013719  0.015060    0.065195  0.139415

# %%
## select columns feature to create the model
from sklearn.model_selection import train_test_split
X = df_sc[['Market_Cap','Owners','Assets']]
y = df_sc['Sales']

## split data for train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
model = LinearRegression().fit(X_train, y_train)

y_pred = model.predict(X_test)

model_score = r2_score(y_test, y_pred)
model_rmse = mean_squared_error(y_test, y_pred, squared = False)
print("R2 Score : ", model_score)
print("RMSE : ", model_rmse)
# Out:
# R2 Score :  0.5665985452748175
# RMSE :  0.052267627227039176

# %% [markdown]
# #### RandomForest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
modelRF = RandomForestRegressor().fit(X_train, y_train)

y_pred = modelRF.predict(X_test)
modelRF_score = r2_score(y_test, y_pred)
modelRF_rmse = mean_squared_error(y_test, y_pred, squared = False)
print("R2 Score : ", modelRF_score)
print("RMSE : ", modelRF_rmse)
# Out:
# R2 Score :  0.4855723357874274
# RMSE :  0.05694423467160753
